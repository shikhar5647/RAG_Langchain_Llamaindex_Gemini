# %%
import os
os.environ["COHERE_API_KEY"] = "WpAQAljuA12bSppkqSrzAaQ8McR0WTfqCRYl21Gq"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"]="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"
os.environ["GOOGLE_API_KEY"] ="AIzaSyAgDr3ptkmYVH1RnX8kwKxdoCbOXyut5uc"

# %%
# !pip install -q langchain openai tiktoken
# !pip install langchain_cohere
# !pip install langchain_community

# %%
# !pip install langchain-google-genai

# %%
from langchain_core.messages import HumanMessage,SystemMessage

# %%
# !pip install langchain_core

# %% [markdown]
# Basic Calling and initiation

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
messages = [
    SystemMessage(
        content="You are a helpful assistant."
    ),
    HumanMessage(
        content="What is the capital of France?"
    ),
]

# %%
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='The capital of France is **Paris**. 🇫🇷 \n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]}, id='run-35d21a39-0b50-4f3a-bf0f-ca70791a92f7-0', usage_metadata={'input_tokens': 14, 'output_tokens': 11, 'total_tokens': 25})

# %%
print(ai_msg.content)
# Out:
# The capital of France is **Paris**. 🇫🇷

# %% [markdown]
# ## Chaining

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant that translates {input_language} to {output_language}.",
        ),
        ("human", "{input}"),
    ]
)

chain = prompt | llm
chain.invoke(
    {
        "input_language": "English",
        "output_language": "German",
        "input": "I love programming.",
    }
)
# Out:
# AIMessage(content='Ich liebe das Programmieren. \n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]}, id='run-dda6d74a-a3ef-4a6c-923a-a1befa0e4de4-0', usage_metadata={'input_tokens': 16, 'output_tokens': 7, 'total_tokens': 23})

# %% [markdown]
# ##Embedding Model

# %% [markdown]
# Embedding with Hugging face open source model

# %%
# !pip install --upgrade --quiet  sentence_transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 3.9 MB/s eta 0:00:00

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# ...

# %%
embedding = hf.embed_query("hi this is Shikhar Dave from Jodhpur , Rajasthan")
len(embedding)
# Out:
# 384

# %%
print(embedding[:5])
# Out:
# [-0.04333382844924927, 0.003482172265648842, -0.021516554057598114, -0.02885144017636776, 0.008735118433833122]

# %% [markdown]
# Embedding with Google-genai

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
vector = embeddings.embed_query("hi this is Shikhar Dave from Jodhpur , Rajasthan")
vector[:5]
# Out:
# [0.017946584150195122,
#  -0.007646150887012482,
#  -0.03949926048517227,
#  -0.04657673090696335,
#  0.06064671277999878]

# %%
vectors = embeddings.embed_documents(
    [
        "Hi",
        "This is Shikhar Dave",
        "From Jodhpur, Rajasthan",
    ]
)
len(vectors), len(vectors[0])
# Out:
# (3, 768)

# %% [markdown]
# ## LLMCHAINS

# %%
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.schema import StrOutputParser

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
template = """List all the colors in a rainbow"""
prompt = PromptTemplate(
    template=template, input_variables=[], output_parser=StrOutputParser()
)

llm_chain = LLMChain(prompt=prompt, llm=llm)
llm_chain.predict()
# Out:
# <ipython-input-29-2459e375f1a6>:6: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(prompt=prompt, llm=llm)
# 'The colors of a rainbow, in order, are:\n\n1. **Red**\n2. **Orange**\n3. **Yellow**\n4. **Green**\n5. **Blue**\n6. **Indigo**\n7. **Violet** \n\nThis is often remembered by the acronym ROYGBIV. \n'

# %% [markdown]
# ## Sequential

# %%
from langchain.prompts import PromptTemplate

post_prompt = PromptTemplate.from_template(
    """You are a business owner. Given the theme of a post, write a social media post to share on my socials.

Theme: {theme}
Content: This is social media post based on the theme above:"""
)

review_prompt = PromptTemplate.from_template(
    """You are an expert social media manager. Given the presented social media post, it is your job to write a review for the post.

Social Media Post:
{post}
Review from a Social Media Expert:"""
)

# %%
chain = (
    {"post": post_prompt | llm | StrOutputParser()}
    | review_prompt
    | llm
    | StrOutputParser()
)
chain.invoke({"theme": "Having a black friday sale with 50% off on everything."})
# Out:
# '## Social Media Post Review:\n\n**Strengths:**\n\n* **Strong hook:** The use of emojis, capital letters, and the phrase "Black Friday is here early" creates a sense of urgency and excitement. \n* **Clear value proposition:**  The "50% OFF EVERYTHING" message is instantly understandable and highly appealing. \n* **Mention of popular products:** Highlighting specific product categories helps potential customers visualize the deals and piques their interest.\n* **Call to action:** The "Shop now" CTA is clear and direct, encouraging immediate action.\n* **Relevant hashtags:** The post uses a good mix of general and industry-specific hashtags to increase visibility.\n\n**Areas for Improvement:**\n\n* **Limited time offer:** While mentioning a limited-time offer adds urgency, specifying the exact duration (e.g., "ends tonight" or "for the next 24 hours") would further encourage immediate action.\n* **Visual appeal:**  Consider adding an eye-catching image or video to further capture atten
# ...

# %%
from langchain.schema.runnable import RunnablePassthrough

post_chain = post_prompt | llm | StrOutputParser()
review_chain = review_prompt | llm | StrOutputParser()
chain = {"post": post_chain} | RunnablePassthrough.assign(review=review_chain)
chain.invoke({"theme": "Having a black friday sale with 50% off on everything."})
# Out:
# {'post': "## IT'S HERE! 🖤 The Black Friday Sale You've Been Waiting For! 🖤\n\nGet ready to shop 'til you drop because EVERYTHING is **50% OFF**! 🎉 \n\nThat's right, you heard correctly - EVERYTHING! 🤩 From [mention a few popular product categories] and more, it's the perfect time to treat yourself or get a head start on your holiday shopping. 🎁\n\n**Sale starts [Date] at [Time] and ends [Date] at [Time].** Don't miss out on these incredible savings! ⏳\n\n➡️ Shop now: [Link to your website]\n\n#blackfriday #sale #deals #shopnow #limitedtimeonly #everything50off #treatyourself #holidayshopping #[yourbusinessname] \n",
# ...
